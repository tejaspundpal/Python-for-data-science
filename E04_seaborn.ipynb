# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data =sns.load_dataset("tips")
sns.relplot(x="total_bill",y="tip",data = data)

# %%
data.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.lineplot(x="total_bill",y="tip",data = data)
plt.title("Title using matplotlib function")
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",kind = 'line',data = data)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", palette="ch:r=-.5,l=.75", data=tips);

# %%
sns.scatterplot(x="total_bill",y="tip",data = data)
plt.title("Title using matplotlib function")
plt.show()

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker",data=data)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker",col="day",data=data)

# %%
sns.catplot(x="total_bill",y="day",hue="time",kind="swarm",data=tips)

# %%
sns.catplot(x="total_bill",y="day",hue="time",kind="boxen",data=tips)

# %%
sns.catplot(x="total_bill",y="day",hue="time",kind="box",data=tips)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)
tips=sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", data=tips)

# %%
sns.catplot(x="day", y="total_bill", jitter=False, data=tips)

# %%
sns.catplot(x="day", y="total_bill", kind="swarm", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm",
data=tips)

# %%
sns.catplot(x="total_bill", y="day", hue="time", kind="swarm", 
data=tips)

# %%
a = np.random.RandomState(0)
x = np.linspace(0,10,500)
y = np.cumsum(a.randn(500,6),0)
plt.plot(x,y)
plt.legend('ABCDEF',ncol = 2,loc = 'upper left')

# %%
titanic=sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Documents\c++\New folder\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\Documents\c++\New folder\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\Documents\c++\New folder\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Documents\c++\New folder\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\Documents\c++\New folder\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\Documents\c++\New folder\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...
