# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("C:\\Users\\Tejas Pundpal\\Documents\\ML\\linera_regression_multivariate\\task\\hiring.csv")
df
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              NaN   70000
# 5           3           7             10.0   62000
# 6          10           7              7.0   72000
# 7          11           7              8.0   80000

# %%
df.isna().sum()
# Out:
# experience         0
# test_score         0
# interview_score    1
# salary             0
# dtype: int64

# %%
df.head()
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              NaN   70000

# %%
df['interview_score'].replace(np.NaN,df['interview_score'].mean(),inplace = True)
#replace missing values with mean of column

# %%
df
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8         9.000000   50000
# 1           0           8         6.000000   45000
# 2           5           6         7.000000   60000
# 3           2          10        10.000000   65000
# 4           7           9         8.142857   70000
# 5           3           7        10.000000   62000
# 6          10           7         7.000000   72000
# 7          11           7         8.000000   80000

# %%
df.to_csv("C:\\Users\\Tejas Pundpal\\Documents\\sem 5\\Data science\\DS exp\\mean_e05.csv")

# %%
df_constvalue=pd.read_csv("C:\\Users\\Tejas Pundpal\\Documents\\ML\\linera_regression_multivariate\\task\\hiring.csv")
df_constvalue
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              NaN   70000
# 5           3           7             10.0   62000
# 6          10           7              7.0   72000
# 7          11           7              8.0   80000

# %%
df_constvalue.fillna(8) #replace missing vlaues with constant value
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              8.0   70000
# 5           3           7             10.0   62000
# 6          10           7              7.0   72000
# 7          11           7              8.0   80000

# %%
df_constvalue.to_csv("C:\\Users\\Tejas Pundpal\\Documents\\sem 5\\Data science\\DS exp\\constvalue_e05.csv")

# %%
df_mode=pd.read_csv("C:\\Users\\Tejas Pundpal\\Documents\\ML\\linera_regression_multivariate\\task\\hiring.csv")
df_mode
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              NaN   70000
# 5           3           7             10.0   62000
# 6          10           7              7.0   72000
# 7          11           7              8.0   80000

# %%
df_mode['interview_score'] = df_mode['interview_score'].fillna(df_mode['interview_score'].mode()[0])
df_mode
#replacing missing value with mode
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              7.0   70000
# 5           3           7             10.0   62000
# 6          10           7              7.0   72000
# 7          11           7              8.0   80000

# %%
df_mode.to_csv("C:\\Users\\Tejas Pundpal\\Documents\\sem 5\\Data science\\DS exp\\mode_e05.csv")

# %%
df_imputed=pd.read_csv("C:\\Users\\Tejas Pundpal\\Documents\\ML\\linera_regression_multivariate\\task\\hiring.csv")
df_imputed
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              NaN   70000
# 5           3           7             10.0   62000
# 6          10           7              7.0   72000
# 7          11           7              8.0   80000

# %%
df_median=pd.read_csv("C:\\Users\\Tejas Pundpal\\Documents\\ML\\linera_regression_multivariate\\task\\hiring.csv")
df_median
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              NaN   70000
# 5           3           7             10.0   62000
# 6          10           7              7.0   72000
# 7          11           7              8.0   80000

# %%
df_median.fillna(df_median)
# Out:
#    experience  test_score  interview_score  salary
# 0           0           8              9.0   50000
# 1           0           8              6.0   45000
# 2           5           6              7.0   60000
# 3           2          10             10.0   65000
# 4           7           9              NaN   70000
# 5           3           7             10.0   62000
# 6          10           7              7.0   72000
# 7          11           7              8.0   80000

# %%
df_median.to_csv("C:\\Users\\Tejas Pundpal\\Documents\\sem 5\\Data science\\DS exp\\medain_e05.csv")
